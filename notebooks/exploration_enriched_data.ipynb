# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/anais/code/anaisdangeot/mood_detector/raw_data/dataset_enriched_s3.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id                  artists  \
# 0         20000       20000  5IgjP7X4th6nMNDh4akUHb              Chris Brown
# 1         20001       20001  3nqQXoyQOWXiESFLlDF1hG     Sam Smith;Kim Petras
# 2         20002       20002  5nCthAh3jt4xKuLJAifAaR               Katy Perry
# 3         20003       20003  48QmG1dfvMuYLxMPt7KSRA       Sean Paul;Dua Lipa
# 4         20004       20004  7BKLCZ1jbUBVqRi2FVlTVw  The Chainsmokers;Halsey
#
#                   album_name                 track_name  popularity  \
# 0          Indigo (Extended)        Under The Influence          96
# 1  Unholy (feat. Kim Petras)  Unholy (feat. Kim Petras)         100
# 2          Harleys In Hawaii          Harleys In Hawaii          73
# 3       Mad Love The Prequel                     No Lie          83
# 4                     Closer                     Closer          84
#
#    duration_ms  explicit  danceability  ...  speechiness  acousticness  \
# ...

# %%
data.shape
# Out:
# (10000, 24)

# %%
data[data['lyrics_extracted']=='999']
# Out:
#       Unnamed: 0.1  Unnamed: 0                track_id  \
# 13           20013       20013  6Uj1ctrBOjOas8xZXGqKk4
# 18           20018       20018  06KyNuuMOX1ROXRhj787tj
# 19           20019       20019  0EH7sgeiFqDa3eS7ieW2zs
# 20           20020       20020  39LLxExYz6ewLAcYrzQQyP
# 21           20021       20021  0tBbt8CrmxbjRP0pueQkyU
# ...            ...         ...                     ...
# 9994         29994       29994  7sl9yknSv01LGm7GXSur1L
# 9995         29995       29995  7beAh9FEDhV8VUQ39fwDyf
# 9997         29997       29997  2p4Y8c7O0Tm48Zk6IAWcTo
# 9998         29998       29998  5gQI9ccczclMrKfPnfxpkD
# 9999         29999       29999  5ruT2dWSHtML4esT7doTzt
#
#                         artists                  album_name  \
# 13                     Doja Cat                  Planet Her
# 18    Charlie Puth;Selena Gomez             Nine Track Mind
# 19            Akon;Hamsika Iyer                      Ra-One
# ...

# %%
df_withlyrics = data[data['lyrics_extracted']!='999']
df_withlyrics.shape
# Out:
# (2718, 24)

# %%
df_en_lyrics = df_withlyrics[df_withlyrics['lyrics_language']=='en']
df_en_lyrics.shape
# Out:
# (2407, 24)

# %%
small_df = df_en_lyrics[['track_id', 'track_genre']]
small_df.groupby(['track_genre']).count()
# Out:
#                 track_id
# track_genre
# dance                516
# dancehall            276
# death-metal          260
# deep-house           264
# detroit-techno        31
# disco                189
# disney                80
# drum-and-bass        171
# dub                  296
# dubstep              324

# %%
small_df
# Out:
#                     track_id track_genre
# 0     5IgjP7X4th6nMNDh4akUHb       dance
# 1     3nqQXoyQOWXiESFLlDF1hG       dance
# 2     5nCthAh3jt4xKuLJAifAaR       dance
# 3     48QmG1dfvMuYLxMPt7KSRA       dance
# 4     7BKLCZ1jbUBVqRi2FVlTVw       dance
# ...                      ...         ...
# 9976  0Oc1IPRBKJnkDIZYTvlIh9     dubstep
# 9981  4g3o3KScQl3MVW8THLDBVQ     dubstep
# 9988  6G1i0Uv6Nkhb9CnksXCfAx     dubstep
# 9993  2tI2DDT95lnvNhlPWZRMJ3     dubstep
# 9996  3pnCeZNsoRXi2b5DbsOpqV     dubstep
#
# [2407 rows x 2 columns]
