# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/anais/code/anaisdangeot/mood_detector/raw_data/dataset_enriched_end.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id  \
# 0        110000      110000  6f3Slt0GbA2bPZlz0aIFXN
# 1        110001      110001  3Nku6gLNqnwUuq8GLkqyhW
# 2        110002      110002  5ialmmuwylzm1xDwHlxpCg
# 3        110003      110003  5YaskwnGDZFDRipaqzbwQx
# 4        110004      110004  0bI7K9Becu2dtXK1Q3cZNB
#
#                                     artists       album_name       track_name  \
# 0                                    Tiësto     The Business     The Business
# 1  Armin van Buuren;Vini Vici;Hilight Tribe     Great Spirit     Great Spirit
# 2             Blastoyz;Sajanka;Liora Itzhak    Indian Spirit    Indian Spirit
# 3                             ATB;Topic;A7S  Your Love (9PM)  Your Love (9PM)
# 4                            Tiësto;KAROL G     Don't Be Shy     Don't Be Shy
#
#    popularity  duration_ms  explicit  danceability  ...  speechiness  \
# 0          82       164000     False         0.798  ...       0.2320
# ...

# %%
data.shape
# Out:
# (4000, 24)

# %%
data[data['lyrics_extracted']=='999']
# Out:
#       Unnamed: 0.1  Unnamed: 0                track_id  \
# 2           110002      110002  5ialmmuwylzm1xDwHlxpCg
# 7           110007      110007  2AzM4cYfa7hyvWRw2T2uT0
# 8           110008      110008  6Rc5E1q0q1wF0XWkUrnXJv
# 10          110010      110010  1NM2NUzlN9SY8z5k4ZfRJB
# 57          110057      110057  65QQ7BX2f45PrU1EF3DLu4
# ...            ...         ...                     ...
# 3990        113990      113990  2A4dSiJmbviL56CBupkh6C
# 3994        113994      113994  4WbOUe6T0sozC7z5ZJgiAA
# 3995        113995      113995  2C3TZjDRiAzdyViavDJ217
# 3996        113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 3998        113998      113998  2e6sXL2bYv4bSz6VTdnfLs
#
#                             artists  \
# 2     Blastoyz;Sajanka;Liora Itzhak
# 7                    Sajanka;Yarden
# 8                           Sajanka
# 10        Armin van Buuren;Hardwell
# 57                    KiLLATK;Popek
# ...                             ...
# 3990                 Lucas Cervetti
# ...

# %%
df_withlyrics = data[data['lyrics_extracted']!='999']

# %%
df_withlyrics[df_withlyrics['lyrics_language']=='en']
# Out:
#       Unnamed: 0.1  Unnamed: 0                track_id            artists  \
# 0           110000      110000  6f3Slt0GbA2bPZlz0aIFXN             Tiësto
# 3           110003      110003  5YaskwnGDZFDRipaqzbwQx      ATB;Topic;A7S
# 4           110004      110004  0bI7K9Becu2dtXK1Q3cZNB     Tiësto;KAROL G
# 5           110005      110005  18asYwWugKjjsihZ0YvRxO     Tiësto;Ava Max
# 6           110006      110006  3Z7CaxQkqbIs1rewKi6v4W  Tiësto;Charli XCX
# ...            ...         ...                     ...                ...
# 3987        113987      113987  4jDhzTYkEG5GloIWwVeVkc      Planetshakers
# 3988        113988      113988  6PM55W7WiUmHVPdUebJP55      Planetshakers
# 3991        113991      113991  0CE0Y6GM75cbrqao8EOAlW       Chris Tomlin
# 3992        113992      113992  3FjOBB4EyIXHYUtSgrIdY9      Jesus Culture
# 3993        113993      113993  4OkMK49i3NApR1KsAIsTf6       Chris Tomlin
#
#                              album_name                   track_name  \
# ...
