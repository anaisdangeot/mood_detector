# %%
# !pip install wordcloud
# !pip install --upgrade pip
# !pip install --upgrade Pillow
# Out:
# Requirement already satisfied: wordcloud in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from wordcloud) (1.23.4)
# Requirement already satisfied: pillow in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from wordcloud) (9.1.1)
# Requirement already satisfied: matplotlib in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: pip in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (23.1.2)
# Requirement already satisfied: Pillow in /home/matt/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (9.1.1)
# Collecting Pillow
#   Using cached Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.1.1
#     Uninstalling Pillow-9.1.1:
#       Successfully uninstalled Pillow-9.1.1
# Successfully installed Pillow-9.5.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud as wc
import sys,os
import numpy as np
import pandas as pd

# %%
text = open('/home/matt/code/anaisdangeot/mood_detector/code/api/lyrics_parts_test.txt',mode="r",encoding='utf-8').read()
plt.figure(figsize=(10,10),facecolor='none')
WordCloud = wc(background_color='rgba(0, 0, 0, 0)').generate(text)
plt.axis('off')
plt.imshow(WordCloud)
